# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import mahotas
import pandas as pd

ruta_carpeta = "dataset/etiquetadas/"
carpeta_destino = f'dataset/etiquetadas'
imagenes = []

for archivo in os.listdir(ruta_carpeta):
    ruta_archivo = os.path.join(ruta_carpeta, archivo)
    if os.path.isfile(ruta_archivo) and archivo.lower().endswith(('.jpg', '.jpeg', '.png')):
        imagenes.append(ruta_archivo)
        
etiquetas = []

df = pd.DataFrame()

for ruta_imagen in imagenes:

    imagen = cv2.imread(ruta_imagen)
    imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

    radius = 15
    zernike = mahotas.features.zernike_moments(imagen, radius)
    
    df = pd.concat([df, pd.DataFrame(zernike).T], ignore_index=True)
    
    nombre_archivo = os.path.basename(ruta_imagen)
    etiqueta = nombre_archivo.split('_')[-1].split('.')[0]
    etiquetas.append(etiqueta)

columnas = ['zernike_' + str(i) for i in range(len(df.columns))]
df.columns = columnas

df['etiqueta'] = etiquetas

df
# Out:
#    zernike_0  zernike_1  zernike_2  zernike_3  zernike_4  zernike_5  \
# 0    0.31831   0.031782   0.000578   0.026028   0.002610   0.005112
# 1    0.31831   0.095765   0.002901   0.074548   0.048996   0.010134
# 2    0.31831   0.003829   0.006730   0.008113   0.016197   0.000103
# 3    0.31831   0.059329   0.039240   0.047496   0.077182   0.025787
# 4    0.31831   0.031299   0.029803   0.025544   0.031027   0.012113
#
#    zernike_6  zernike_7  zernike_8  zernike_9  ...  zernike_16  zernike_17  \
# 0   0.020872   0.020842   0.036061   0.011458  ...    0.008247    0.013727
# 1   0.000776   0.015320   0.005920   0.021481  ...    0.021552    0.018327
# 2   0.001130   0.007499   0.005354   0.007592  ...    0.015977    0.007175
# 3   0.010296   0.044949   0.049252   0.030790  ...    0.041595    0.071459
# 4   0.005905   0.009178   0.004647   0.013635  ...    0.012396    0.011546
#
#    zernike_18  zernike_19  zernike_20  zernike_21  zernike_22  zernike_23  \
# 0    0.016457    0.012572    0.005747    0.044114    0.026255    0.022901
# 1    0.023628    0.008746    0.033033    0.025751    0.002655    0.018170
# 2    0.006269    0.009845    0.003951    0.003387    0.010585    0.016169
# 3    0.028684    0.047354    0.031823    0.008112    0.036644    0.052102
# 4    0.012393    0.007244    0.013990    0.008310    0.001997    0.005741
#
#    zernike_24  etiqueta
# 0    0.036254         4
# 1    0.025829         1
# 2    0.004811         2
# 3    0.044371         3
# 4    0.006114         5
#
# [5 rows x 26 columns]
