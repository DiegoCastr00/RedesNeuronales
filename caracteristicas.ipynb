# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import mahotas
import pandas as pd

ruta_carpeta = "dataset"
imagenes = []

for archivo in os.listdir(ruta_carpeta):
    ruta_archivo = os.path.join(ruta_carpeta, archivo)
    if os.path.isfile(ruta_archivo) and archivo.lower().endswith(('.jpg', '.jpeg', '.png')):
        imagenes.append(ruta_archivo)
        
print(len(imagenes))
# Out:
# 3000

# %%
etiquetas = []
df = pd.DataFrame()
for ruta_imagen in imagenes:

    imagen = cv2.imread(ruta_imagen)
    imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

    radius = 15
    zernike = mahotas.features.zernike_moments(imagen, radius)
    
    df = pd.concat([df, pd.DataFrame(zernike).T], ignore_index=True)
    
    nombre_archivo = os.path.basename(ruta_imagen)

    etiqueta = nombre_archivo.split('_')[-1].split('.')[0]
    etiquetas.append(etiqueta)
columnas = ['zernike_' + str(i) for i in range(len(df.columns))]
df.columns = columnas
df['etiqueta'] = etiquetas
df
# Out:
#       zernike_0  zernike_1  zernike_2  zernike_3  zernike_4  zernike_5  \
# 0       0.31831   0.046112   0.059152   0.005395   0.058404   0.081963
# 1       0.31831   0.255078   0.106823   0.175700   0.038028   0.041709
# 2       0.31831   0.045304   0.083790   0.058559   0.079803   0.112529
# 3       0.31831   0.180307   0.030431   0.026109   0.131627   0.049110
# 4       0.31831   0.080460   0.023726   0.018438   0.049069   0.067158
# ...         ...        ...        ...        ...        ...        ...
# 2995    0.31831   0.012942   0.009177   0.005514   0.006587   0.004291
# 2996    0.31831   0.100000   0.024162   0.052053   0.120116   0.132093
# 2997    0.31831   0.008867   0.011160   0.007765   0.011130   0.015535
# 2998    0.31831   0.065584   0.053152   0.135844   0.020404   0.028526
# 2999    0.31831   0.027950   0.023354   0.046373   0.019971   0.041694
#
#       zernike_6  zernike_7  zernike_8  zernike_9  ...  zernike_16  zernike_17  \
# 0      0.051151   0.020409   0.044036   0.101319  ...    0.126187    0.058072
# 1      0.062081   0.091666   0.054502   0.028771  ...    0.028359    0.077704
# 2      0.061911   0.012798   0.133335   0.022471  ...    0.007810    0.010864
# 3      0.051890   0.030853   0.041859   0.069559  ...    0.039557    0.038084
# 4      0.012145   0.019118   0.014653   0.030231  ...    0.015098    0.037243
# ...         ...        ...        ...        ...  ...         ...         ...
# 2995   0.002055   0.008709   0.005137   0.005626  ...    0.013620    0.007946
# 2996   0.041430   0.049644   0.044958   0.020832  ...    0.056158    0.058932
# 2997   0.000424   0.003798   0.003628   0.012286  ...    0.017363    0.013936
# 2998   0.050206   0.094251   0.074220   0.019588  ...    0.024442    0.009936
# 2999   0.021499   0.016129   0.016475   0.005933  ...    0.042170    0.023705
#
#       zernike_18  zernike_19  zernike_20  zernike_21  zernike_22  zernike_23  \
# 0       0.080423    0.112755    0.140770    0.011339    0.083177    0.077802
# 1       0.059823    0.039243    0.030870    0.005191    0.042560    0.030889
# 2       0.040623    0.097917    0.028836    0.007237    0.046437    0.004793
# 3       0.014572    0.011066    0.054910    0.051775    0.052866    0.028627
# 4       0.013189    0.005922    0.010676    0.012476    0.001858    0.020612
# ...          ...         ...         ...         ...         ...         ...
# 2995    0.002946    0.009792    0.010958    0.005170    0.006321    0.008276
# 2996    0.044819    0.011354    0.021300    0.051212    0.057261    0.029450
# 2997    0.005598    0.008353    0.003621    0.005007    0.011533    0.005212
# 2998    0.014465    0.024377    0.042527    0.043559    0.037707    0.029849
# 2999    0.043524    0.012704    0.041546    0.010355    0.020292    0.014510
#
#       zernike_24  etiqueta
# 0       0.101801         2
# 1       0.023665         1
# 2       0.097436         3
# 3       0.033179         3
# 4       0.011208         1
# ...          ...       ...
# 2995    0.009956         2
# 2996    0.020202         2
# 2997    0.005731         2
# 2998    0.035232         1
# 2999    0.027388         1
#
# [3000 rows x 26 columns]

# %%
df.to_csv('Zernike.csv', index=False)

# %%
from skimage.feature import hog

etiquetas = []
HOG = pd.DataFrame()
for ruta_imagen in imagenes:

    imagen = cv2.imread(ruta_imagen)
    imagen = cv2.cvtColor(imagen, cv2.COLOR_RGB2GRAY)

    hog_descriptor = hog(imagen, orientations=8, pixels_per_cell=(16, 16),
                        cells_per_block=(1, 1), visualize=False)

    HOG = pd.concat([HOG, pd.DataFrame(hog_descriptor).T], ignore_index=True)
    
    nombre_archivo = os.path.basename(ruta_imagen)
    etiqueta = nombre_archivo.split('_')[-1].split('.')[0]
    etiquetas.append(etiqueta)
    
columnas = ['HOG_' + str(i) for i in range(len(HOG.columns))]
HOG.columns = columnas
HOG['etiqueta'] = etiquetas
HOG
# Out:
#         HOG_0     HOG_1     HOG_2     HOG_3     HOG_4     HOG_5     HOG_6  \
# 0    0.353602  0.009274  0.164170  0.017100  0.460336  0.460336  0.460336
# 1    0.112708  0.024811  0.075740  0.676438  0.676438  0.170130  0.183616
# 2    0.564895  0.000000  0.549232  0.000000  0.613796  0.000000  0.049930
# 3    0.505352  0.088141  0.269565  0.505352  0.505352  0.091017  0.273707
# 4    0.441929  0.071562  0.441929  0.441929  0.441929  0.211461  0.385160
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.514905  0.304971  0.077041  0.117485  0.514905  0.227182  0.200654
# 896  0.185188  0.108409  0.274240  0.609215  0.609215  0.258808  0.234165
# 897  0.379522  0.267135  0.379522  0.379522  0.379522  0.285392  0.356379
# 898  0.569911  0.077343  0.315092  0.109379  0.569911  0.144694  0.399265
# 899  0.477812  0.115180  0.143356  0.020361  0.477812  0.229236  0.477812
#
#         HOG_7     HOG_8     HOG_9  ...  HOG_1271  HOG_1272  HOG_1273  \
# 0    0.460336  0.365052  0.365052  ...  0.093148  0.382432  0.353215
# 1    0.056114  0.185983  0.011596  ...  0.122708  0.746169  0.242857
# 2    0.000000  0.499010  0.000000  ...  0.561552  0.618711  0.312928
# 3    0.265001  0.353553  0.353553  ...  0.083368  0.226856  0.141326
# 4    0.143559  0.370391  0.370391  ...  0.366667  0.295768  0.304523
# ..        ...       ...       ...  ...       ...       ...       ...
# 895  0.514905  0.360368  0.301569  ...  0.353553  0.397399  0.397399
# 896  0.121017  0.363811  0.363811  ...  0.152835  0.382601  0.333232
# 897  0.379522  0.085409  0.001317  ...  0.279512  0.416897  0.166786
# 898  0.229836  0.465437  0.000000  ...  0.529721  0.353553  0.353553
# 899  0.477812  0.585205  0.109815  ...  0.641178  0.479977  0.120872
#
#      HOG_1274  HOG_1275  HOG_1276  HOG_1277  HOG_1278  HOG_1279  etiqueta
# 0    0.382432  0.382432  0.382432  0.241461  0.382432  0.292683         3
# 1    0.171101  0.000000  0.105639  0.029527  0.547131  0.208788         3
# 2    0.184886  0.016874  0.128036  0.077759  0.282068  0.618711         1
# 3    0.405478  0.405478  0.405478  0.405478  0.405478  0.326347         3
# 4    0.390311  0.390311  0.390311  0.390311  0.390311  0.240984         3
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.321920  0.094352  0.397399  0.312785  0.397399  0.397399         3
# 896  0.382601  0.382601  0.382601  0.382601  0.382601  0.103223         3
# 897  0.416897  0.303886  0.416897  0.416897  0.416897  0.104026         1
# 898  0.353553  0.353553  0.353553  0.353553  0.353553  0.353553         1
# 899  0.107264  0.479977  0.479977  0.095089  0.208159  0.479977         1
#
# [900 rows x 1281 columns]

# %%
HOG.to_csv('HOG.csv', index=False)

# %%
from skimage.feature import hog

etiquetas = []
HOG_cv2 = pd.DataFrame()
for ruta_imagen in imagenes:

    imagen = cv2.imread(ruta_imagen)
    imagen = cv2.cvtColor(imagen, cv2.COLOR_RGB2GRAY)
    
    cell_size = (16, 16)
    win_size = (imagen.shape[1] // cell_size[1] * cell_size[1], imagen.shape[0] // cell_size[0] * cell_size[0])
    block_size = (2 * cell_size[1], 2 * cell_size[0])
    block_stride = cell_size
    num_bins = 4
    
    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, num_bins)
    
    hog_descriptor = hog.compute(imagen)
    
    HOG_cv2 = pd.concat([HOG_cv2, pd.DataFrame(hog_descriptor).T], ignore_index=True)
    
    nombre_archivo = os.path.basename(ruta_imagen)
    etiqueta = nombre_archivo.split('_')[-1].split('.')[0]
    etiquetas.append(etiqueta)
    
columnas = ['HOG_' + str(i) for i in range(len(HOG_cv2.columns))]
HOG_cv2.columns = columnas
HOG_cv2['etiqueta'] = etiquetas
HOG_cv2
# Out:
