# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Zernike.csv')
df
# Out:
#       zernike_0  zernike_1  zernike_2  zernike_3  zernike_4  zernike_5  \
# 0       0.31831   0.126468   0.032179   0.140855   0.043521   0.072145
# 1       0.31831   0.003660   0.010459   0.003856   0.005304   0.010926
# 2       0.31831   0.108501   0.037348   0.045015   0.029620   0.023150
# 3       0.31831   0.030550   0.014723   0.016975   0.011533   0.010684
# 4       0.31831   0.038985   0.007089   0.038553   0.038862   0.007818
# ...         ...        ...        ...        ...        ...        ...
# 3195    0.31831   0.025668   0.022696   0.021321   0.012361   0.017514
# 3196    0.31831   0.076725   0.095450   0.115524   0.032047   0.126287
# 3197    0.31831   0.146573   0.078176   0.077685   0.017320   0.010738
# 3198    0.31831   0.030744   0.063994   0.027631   0.020745   0.016729
# 3199    0.31831   0.018293   0.011354   0.013202   0.002764   0.029768
#
#       zernike_6  zernike_7  zernike_8  zernike_9  ...  zernike_16  zernike_17  \
# 0      0.011149   0.088304   0.061251   0.098969  ...    0.098359    0.041904
# 1      0.010754   0.006278   0.004272   0.004371  ...    0.006052    0.010069
# 2      0.031503   0.028422   0.044902   0.017866  ...    0.015276    0.019676
# 3      0.006808   0.011477   0.003908   0.007157  ...    0.013688    0.003091
# 4      0.034952   0.057674   0.055713   0.029930  ...    0.022483    0.024061
# ...         ...        ...        ...        ...  ...         ...         ...
# 3195   0.001831   0.007732   0.002336   0.003849  ...    0.003640    0.010221
# 3196   0.123857   0.052768   0.036476   0.067718  ...    0.015061    0.017283
# 3197   0.047210   0.040737   0.037791   0.030813  ...    0.020579    0.048052
# 3198   0.021654   0.071580   0.011605   0.062228  ...    0.059949    0.070107
# 3199   0.011925   0.014569   0.020834   0.022008  ...    0.023903    0.021150
#
#       zernike_18  zernike_19  zernike_20  zernike_21  zernike_22  zernike_23  \
# 0       0.016363    0.067482    0.071087    0.021887    0.034568    0.036322
# 1       0.013308    0.012834    0.019264    0.011063    0.005188    0.005662
# 2       0.037275    0.018729    0.048210    0.003628    0.033675    0.018454
# 3       0.021424    0.008392    0.015043    0.014418    0.005478    0.002074
# 4       0.038598    0.024496    0.068471    0.061572    0.045153    0.034333
# ...          ...         ...         ...         ...         ...         ...
# 3195    0.012013    0.005423    0.004967    0.003438    0.007713    0.006678
# 3196    0.064061    0.050660    0.019417    0.025075    0.038207    0.095487
# 3197    0.044343    0.027123    0.011038    0.004959    0.027709    0.009058
# 3198    0.052138    0.009046    0.026742    0.013963    0.035160    0.027681
# 3199    0.028440    0.017808    0.022012    0.008943    0.025093    0.043688
#
#       zernike_24  etiqueta
# 0       0.026301         3
# 1       0.002499         4
# 2       0.058992         3
# 3       0.006303         1
# 4       0.031966         3
# ...          ...       ...
# 3195    0.010469         2
# 3196    0.069205         1
# 3197    0.003983         4
# 3198    0.020302         3
# 3199    0.028339         4
#
# [3200 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200 entries, 0 to 3199
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zernike_0   3200 non-null   float64
#  1   zernike_1   3200 non-null   float64
#  2   zernike_2   3200 non-null   float64
#  3   zernike_3   3200 non-null   float64
#  4   zernike_4   3200 non-null   float64
#  5   zernike_5   3200 non-null   float64
#  6   zernike_6   3200 non-null   float64
#  7   zernike_7   3200 non-null   float64
#  8   zernike_8   3200 non-null   float64
#  9   zernike_9   3200 non-null   float64
#  10  zernike_10  3200 non-null   float64
#  11  zernike_11  3200 non-null   float64
#  12  zernike_12  3200 non-null   float64
#  13  zernike_13  3200 non-null   float64
#  14  zernike_14  3200 non-null   float64
#  15  zernike_15  3200 non-null   float64
#  16  zernike_16  3200 non-null   float64
#  17  zernike_17  3200 non-null   float64
#  18  zernike_18  3200 non-null   float64
#  19  zernike_19  3200 non-null   float64
#  20  zernike_20  3200 non-null   float64
#  21  zernike_21  3200 non-null   float64
#  22  zernike_22  3200 non-null   float64
#  23  zernike_23  3200 non-null   float64
#  24  zernike_24  3200 non-null   float64
#  25  etiqueta    3200 non-null   int64
# dtypes: float64(25), int64(1)
# memory usage: 650.1 KB

# %%
df['etiqueta'].value_counts()
# Out:
# etiqueta
# 3    1606
# 4     930
# 1     422
# 2     242
# Name: count, dtype: int64

# %%
df['etiqueta'].isnull().any()
# Out:
# False

# %%
print(df.describe())
# Out:
#          zernike_0    zernike_1    zernike_2    zernike_3    zernike_4  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean      0.318210     0.044744     0.028752     0.030604     0.024384
# std       0.005627     0.047826     0.037298     0.035454     0.026892
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.318310     0.009970     0.004871     0.006698     0.006628
# 50%       0.318310     0.028322     0.015284     0.019293     0.015079
# 75%       0.318310     0.063907     0.038855     0.042253     0.033027
# max       0.318310     0.409218     0.351841     0.372928     0.243105
#
#          zernike_5    zernike_6    zernike_7    zernike_8    zernike_9  ...  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000  ...
# mean      0.025668     0.019136     0.021270     0.021622     0.020733  ...
# std       0.028549     0.024124     0.023615     0.023672     0.021956  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.007172     0.004163     0.006321     0.006016     0.007766  ...
# 50%       0.015911     0.010820     0.013134     0.013727     0.013379  ...
# 75%       0.034820     0.024445     0.027585     0.029206     0.025946  ...
# max       0.315953     0.264889     0.251129     0.316088     0.252423  ...
#
#         zernike_16   zernike_17   zernike_18   zernike_19   zernike_20  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean      0.019116     0.019293     0.019478     0.019377     0.015644
# std       0.017978     0.017606     0.016664     0.018064     0.018537
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.008524     0.009022     0.009491     0.007883     0.004366
# 50%       0.014111     0.014408     0.014437     0.014912     0.009652
# 75%       0.022908     0.023011     0.023879     0.023993     0.020259
# max       0.315883     0.229040     0.170998     0.203279     0.264093
#
#         zernike_21   zernike_22   zernike_23   zernike_24     etiqueta
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean      0.016827     0.016918     0.016815     0.017281     2.951250
# std       0.017222     0.017328     0.015436     0.017096     0.944273
# min       0.000000     0.000000     0.000000     0.000000     1.000000
# 25%       0.006875     0.006363     0.006858     0.007050     3.000000
# 50%       0.011914     0.011388     0.012021     0.011739     3.000000
# 75%       0.021016     0.021382     0.020985     0.021359     4.000000
# max       0.204836     0.183834     0.125307     0.188401     4.000000
#
# [8 rows x 26 columns]

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
sns.boxplot(data=df, x='etiqueta', y='zernike_24', palette = "Pastel1", hue='etiqueta') 
plt.title('Boxplot ')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
sns.histplot(data=df, x='zernike_2', hue="etiqueta", element="step", common_norm=False, kde=True)
plt.title('Histograma')
plt.show()

# %%
X = df.drop('etiqueta', axis=1)
y = df['etiqueta']
print(X.shape)
print(y.shape)
# Out:
# (3200, 25)
# (3200,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# Asumiendo que X son tus características y y son tus etiquetas
X = df.drop('etiqueta', axis=1)
y = df['etiqueta']

modelo = RandomForestClassifier()

# Realizar la validación cruzada k-fold
scores = cross_val_score(modelo, X, y, cv=5)

print(f'Scores de validación cruzada: {scores}')
print(f'Promedio de scores: {scores.mean()}')
# Out:
# Scores de validación cruzada: [0.53125   0.5375    0.5265625 0.528125  0.5265625]
# Promedio de scores: 0.53
